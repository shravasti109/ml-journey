# %%
# !pip install nbformat

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ── 1. OUR SMALL DATASET ──────────────────────
data = {
    'size_sqft': [650, 785, 900, 1050, 1200, 1350, 1480, 1600, 1750, 1900, 2050, 2200],
    'price_1000s': [70, 85, 95, 110, 128, 140, 155, 162, 178, 191, 205, 218]
}

# %%
df = pd.DataFrame(data)
df.head(2)
# Out:
#    size_sqft  price_1000s
# 0        650           70
# 1        785           85

# %%
X = df['size_sqft'].values        # feature
y = df['price_1000s'].values      # target

# ── 3. OLS — CLOSED FORM SOLUTION ─────────────
# m = Σ(xi - x̄)(yi - ȳ) / Σ(xi - x̄)²
# b = ȳ - m * x̄

x_mean = np.mean(X)
y_mean = np.mean(y)

numerator   = np.sum((X - x_mean) * (y - y_mean))
denominator = np.sum((X - x_mean) ** 2)

# %%
m = numerator / denominator
m
# Out:
# np.float64(0.09528440282055785)

# %%
b = y_mean - m * x_mean
b
# Out:
# np.float64(10.438693857521997)

# %%
y_prep = []
for i in range(len(X)):
    y_prep.append(round(y_pred[i], 1))

print(y_prep)
# Out:
# [np.float64(72.4), np.float64(85.2), np.float64(96.2), np.float64(110.5), np.float64(124.8), np.float64(139.1), np.float64(151.5), np.float64(162.9), np.float64(177.2), np.float64(191.5), np.float64(205.8), np.float64(220.1)]

# %%
mse  = np.mean((y - y_pred) ** 2)
rmse = np.sqrt(mse)
mae  = np.mean(np.abs(y - y_pred))

ss_tot = np.sum((y - y_mean) ** 2)
ss_res = np.sum((y - y_pred) ** 2)
r2     = 1 - (ss_res / ss_tot)

print(f"\n── Metrics ──")
print(f"MSE  = {mse:.4f}")
print(f"RMSE = {rmse:.4f}")
print(f"MAE  = {mae:.4f}")
print(f"R²   = {r2:.6f}")
# Out:
# ── Metrics ──
# MSE  = 3.1387
# RMSE = 1.7717
# MAE  = 1.4169
# R²   = 0.998539
